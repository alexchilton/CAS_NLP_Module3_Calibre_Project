# %%
import os

# Delete the cached metadata
METADATA_FILE = 'calibre_metadata.json'
EMBEDDING_FILE = 'calibre_book_embeddings.pkl'

if os.path.exists(METADATA_FILE):
    os.remove(METADATA_FILE)
    print(f"✓ Deleted {METADATA_FILE}")

if os.path.exists(EMBEDDING_FILE):
    os.remove(EMBEDDING_FILE)
    print(f"✓ Deleted {EMBEDDING_FILE}")

print("\n✓ Cache cleared. Now re-run the main setup cell.")
# Out:
# ✓ Cache cleared. Now re-run the main setup cell.

# %%
# Cell 1: Environment Setup (MUST RUN FIRST)
import os
import warnings

# Critical: Set BEFORE any other imports
os.environ['HF_HUB_DISABLE_PROGRESS_BARS'] = '1'
os.environ['HF_HUB_OFFLINE'] = '1'
os.environ['TRANSFORMERS_OFFLINE'] = '1'
os.environ['TOKENIZERS_PARALLELISM'] = 'false'
warnings.filterwarnings("ignore")

print("✓ Environment configured")
# Out:
# ✓ Environment configured

# %%
# Install dependencies (run this cell first)
 #pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
 #pip install sentence-transformers scikit-learn tqdm

# %%
# Cell 2: Imports
import pickle
import subprocess
import json
import torch
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from IPython.display import display, HTML

print(f"PyTorch version: {torch.__version__}")
print(f"MPS available: {torch.backends.mps.is_available()}")

# Configuration
#CALIBRE_LIBRARY_PATH = os.path.expanduser("~/calibre_semantic_test")
CALIBRE_LIBRARY_PATH = os.path.expanduser("~/Calibre Library")
EMBEDDING_FILE = 'calibre_book_embeddings.pkl'
METADATA_FILE = 'calibre_metadata.json'

device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}\n")
# Out:
# PyTorch version: 2.8.0
# MPS available: True
# Using device: mps

# %%
# STEP 1: EXTRACT METADATA FROM CALIBRE
# ============================================================================

def get_calibre_metadata(library_path):
    """
    Extracts metadata from Calibre database using calibredb CLI.
    Returns a dictionary of book_id -> metadata
    """
    print(f"📚 Extracting metadata from: {library_path}")

    cmd = [
        'calibredb', 'list',
        '--library-path', library_path,
        '--for-machine'
    ]

    result = subprocess.run(cmd, capture_output=True, text=True)

    if result.returncode != 0:
        raise Exception(f"Failed to read Calibre library: {result.stderr}")

    books = json.loads(result.stdout)
    print(f"✓ Found {len(books)} books in library\n")

    return books


def create_searchable_text(book):
    """
    Combines relevant metadata fields into a single searchable text.
    Fields are weighted by importance (repeated = more important).
    """
    parts = []

    # Title (most important - include twice)
    if book.get('title'):
        parts.append(f"Title: {book['title']}")
        parts.append(book['title'])

    # Authors
    if book.get('authors'):
        authors = ', '.join(book['authors']) if isinstance(book['authors'], list) else book['authors']
        parts.append(f"Authors: {authors}")

    # Series
    if book.get('series'):
        parts.append(f"Series: {book['series']}")

    # Tags/Genres (very important for semantic search)
    if book.get('tags'):
        tags = ', '.join(book['tags']) if isinstance(book['tags'], list) else book['tags']
        parts.append(f"Tags: {tags}")
        parts.append(tags)  # Include twice for emphasis

    # Publisher
    if book.get('publisher'):
        parts.append(f"Publisher: {book['publisher']}")

    # Description/Comments (most descriptive - include twice)
    if book.get('comments'):
        import re
        clean_comments = re.sub(r'<[^>]+>', '', book['comments'])
        parts.append(f"Description: {clean_comments}")
        parts.append(clean_comments)

    return " | ".join(parts)


def prepare_metadata_for_embedding(books):
    """
    Prepares book metadata for embedding.
    Returns: dict of book_id -> searchable_text and dict of book_id -> full_metadata
    """
    searchable_texts = {}
    book_metadata = {}

    print("🔄 Preparing metadata for embedding...")
    total = len(books)
    for idx, book in enumerate(books, 1):
        book_id = str(book['id'])
        searchable_texts[book_id] = create_searchable_text(book)
        book_metadata[book_id] = book

        # Simple progress indicator
        if idx % 10 == 0 or idx == total:
            print(f"   Processed {idx}/{total} books...")

    print(f"✓ Processed {len(searchable_texts)} books\n")
    return searchable_texts, book_metadata

# %%
# ============================================================================
# STEP 2: LOAD OR CREATE EMBEDDINGS
# ============================================================================

def load_or_create_embeddings(searchable_texts, model):
    """
    Loads existing embeddings or creates new ones using PyTorch.
    """
    if os.path.exists(EMBEDDING_FILE):
        print("📂 Loading existing embeddings from disk...")
        with open(EMBEDDING_FILE, 'rb') as f:
            embeddings_dict = pickle.load(f)
        print(f"✓ Loaded embeddings for {len(embeddings_dict)} books\n")
        return embeddings_dict

    print("🧠 Generating embeddings for book metadata...")
    print(f"   Model: {model}")
    print(f"   Device: {device}")

    book_ids = list(searchable_texts.keys())
    texts_to_embed = list(searchable_texts.values())

    # Generate embeddings with PyTorch backend
    embeddings = model.encode(
        texts_to_embed,
        batch_size=32,
        show_progress_bar=True,
        convert_to_numpy=True,
        device=device
    )

    # Map book IDs to embeddings
    embeddings_dict = {book_id: emb for book_id, emb in zip(book_ids, embeddings)}

    # Save embeddings
    with open(EMBEDDING_FILE, 'wb') as f:
        pickle.dump(embeddings_dict, f)
    print(f"✓ Embeddings saved to '{EMBEDDING_FILE}'\n")

    return embeddings_dict

# %%
# ============================================================================
# STEP 3: SEARCH FUNCTIONS
# ============================================================================

def semantic_search(query, embeddings_dict, book_metadata, model, top_n=10):
    """
    Performs semantic search on the book metadata using cosine similarity.
    """
    # Embed the query
    query_embedding = model.encode(query, convert_to_numpy=True, device=device).reshape(1, -1)

    # Calculate similarities
    similarities = {}
    for book_id, book_embedding in embeddings_dict.items():
        book_embedding = book_embedding.reshape(1, -1)
        similarity = cosine_similarity(query_embedding, book_embedding)[0][0]
        similarities[book_id] = similarity

    # Sort by similarity
    sorted_results = sorted(similarities.items(), key=lambda x: x[1], reverse=True)

    # Return top N with full metadata
    results = []
    for book_id, score in sorted_results[:top_n]:
        results.append({
            'score': score,
            'metadata': book_metadata[book_id]
        })

    return results


def display_results_jupyter(results):
    """
    Displays search results in Jupyter with nice formatting.
    """
    display(HTML("<h2>🔍 Search Results</h2>"))

    for i, result in enumerate(results, 1):
        book = result['metadata']
        score = result['score']

        # Build HTML for each book
        html = f"""
        <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
            <h3 style="margin-top: 0; color: #2c3e50;">
                {i}. {book.get('title', 'Unknown Title')}
                <span style="float: right; color: #27ae60; font-size: 0.8em;">
                    Similarity: {score:.4f}
                </span>
            </h3>
        """

        # Authors
        if book.get('authors'):
            authors = ', '.join(book['authors']) if isinstance(book['authors'], list) else book['authors']
            html += f"<p><strong>Authors:</strong> {authors}</p>"

        # Series
        if book.get('series'):
            series_info = book['series']
            if book.get('series_index'):
                series_info += f" #{book['series_index']}"
            html += f"<p><strong>Series:</strong> {series_info}</p>"

        # Tags
        if book.get('tags'):
            tags = book['tags'] if isinstance(book['tags'], list) else [book['tags']]
            tag_badges = ' '.join([f'<span style="background-color: #3498db; color: white; padding: 2px 8px; border-radius: 3px; font-size: 0.85em; margin-right: 5px;">{tag}</span>' for tag in tags])
            html += f"<p><strong>Tags:</strong> {tag_badges}</p>"

        # Publisher and date
        pub_info = []
        if book.get('publisher'):
            pub_info.append(book['publisher'])
        if book.get('pubdate'):
            pub_info.append(str(book['pubdate']))
        if pub_info:
            html += f"<p><strong>Published:</strong> {', '.join(pub_info)}</p>"

        # Rating
        if book.get('rating'):
            stars = '★' * int(book['rating']) + '☆' * (5 - int(book['rating']))
            html += f"<p><strong>Rating:</strong> {stars}</p>"

        # Description preview
        if book.get('comments'):
            import re
            clean_comments = re.sub(r'<[^>]+>', '', book['comments'])
            preview = clean_comments[:300] + "..." if len(clean_comments) > 300 else clean_comments
            html += f"<p><strong>Description:</strong> <em>{preview}</em></p>"

        html += f"<p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> {book['id']}</p>"
        html += "</div>"

        display(HTML(html))


def display_results_text(results):
    """
    Displays search results in plain text (for non-Jupyter environments).
    """
    print("\n" + "="*80)
    print("🔍 SEARCH RESULTS")
    print("="*80)

    for i, result in enumerate(results, 1):
        book = result['metadata']
        score = result['score']

        print(f"\n{i}. [{score:.4f}] {book.get('title', 'Unknown Title')}")

        if book.get('authors'):
            authors = ', '.join(book['authors']) if isinstance(book['authors'], list) else book['authors']
            print(f"   Authors: {authors}")

        if book.get('series'):
            series_info = book['series']
            if book.get('series_index'):
                series_info += f" #{book['series_index']}"
            print(f"   Series: {series_info}")

        if book.get('tags'):
            tags = ', '.join(book['tags']) if isinstance(book['tags'], list) else book['tags']
            print(f"   Tags: {tags}")

        pub_info = []
        if book.get('publisher'):
            pub_info.append(book['publisher'])
        if book.get('pubdate'):
            pub_info.append(str(book['pubdate']))
        if pub_info:
            print(f"   Published: {', '.join(pub_info)}")

        if book.get('rating'):
            stars = '★' * int(book['rating']) + '☆' * (5 - int(book['rating']))
            print(f"   Rating: {stars}")

        if book.get('comments'):
            import re
            clean_comments = re.sub(r'<[^>]+>', '', book['comments'])
            preview = clean_comments[:200] + "..." if len(clean_comments) > 200 else clean_comments
            print(f"   Description: {preview}")

        print(f"   Calibre ID: {book['id']}")
        print("-" * 80)

# %%
# Cell 4: Main Setup
print("="*80)
print("📚 CALIBRE SEMANTIC SEARCH SYSTEM")
print("="*80)
print()

# Load metadata
if os.path.exists(METADATA_FILE):
    print("📂 Loading cached metadata...")
    with open(METADATA_FILE, 'r') as f:
        books = json.load(f)
    print(f"✓ Loaded {len(books)} books\n")
else:
    books = get_calibre_metadata(CALIBRE_LIBRARY_PATH)
    with open(METADATA_FILE, 'w') as f:
        json.dump(books, f)

# Prepare searchable texts
searchable_texts, book_metadata = prepare_metadata_for_embedding(books)

# Load model (offline mode)
print("🤖 Loading embedding model...")
model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')
print("   ✓ Loaded on CPU")

if device == 'mps':
    model = model.to('mps')
    print("   ✓ Moved to MPS")

print("✓ Model ready\n")

# Load or create embeddings
embeddings_dict = load_or_create_embeddings(searchable_texts, model)

print("="*80)
print("✅ READY TO SEARCH!")
print("="*80)
print()
# Out:
# ================================================================================
# 📚 CALIBRE SEMANTIC SEARCH SYSTEM
# ================================================================================
#
# 📚 Extracting metadata from: /Users/alexchilton/Calibre Library
# ✓ Found 14806 books in library
#
# 🔄 Preparing metadata for embedding...
#    Processed 10/14806 books...
#    Processed 20/14806 books...
#    Processed 30/14806 books...
#    Processed 40/14806 books...
#    Processed 50/14806 books...
#    Processed 60/14806 books...
#    Processed 70/14806 books...
#    Processed 80/14806 books...
#    Processed 90/14806 books...
#    Processed 100/14806 books...
#    Processed 110/14806 books...
#    Processed 120/14806 books...
#    Processed 130/14806 books...
#    Processed 140/14806 books...
#    Processed 150/14806 books...
#    Processed 160/14806 books...
#    Processed 170/14806 books...
#    Processed 180/14806 books...
#    Processed 190/14806 books...
#    Processed 200/14806 books...
#    Processed 210/14806 books...
#    Processed 220/14806 books...
#    Processed 230/14806 books...
#    Processed 240/14806 books...
#    Processed 250/14806 books...
#    Processed 260/14806 books...
#    Processed 270/14806 books...
#    Processed 280/14806 books...
#    Processed 290/14806 books...
#    Processed 300/14806 books...
#    Processed 310/14806 books...
#    Processed 320/14806 books...
#    Processed 330/14806 books...
#    Processed 340/14806 books...
#    Processed 350/14806 books...
#    Processed 360/14806 books...
#    Processed 370/14806 books...
#    Processed 380/14806 books...
#    Processed 390/14806 books...
#    Processed 400/14806 books...
#    Processed 410/14806 books...
#    Processed 420/14806 books...
#    Processed 430/14806 books...
#    Processed 440/14806 books...
#    Processed 450/14806 books...
#    Processed 460/14806 books...
#    Processed 470/14806 books...
#    Processed 480/14806 books...
#    Processed 490/14806 books...
#    Processed 500/14806 books...
#    Processed 510/14806 books...
#    Processed 520/14806 books...
#    Processed 530/14806 books...
#    Processed 540/14806 books...
#    Processed 550/14806 books...
#    Processed 560/14806 books...
#    Processed 570/14806 books...
#    Processed 580/14806 books...
#    Processed 590/14806 books...
#    Processed 600/14806 books...
#    Processed 610/14806 books...
#    Processed 620/14806 books...
#    Processed 630/14806 books...
#    Processed 640/14806 books...
#    Processed 650/14806 books...
#    Processed 660/14806 books...
#    Processed 670/14806 books...
#    Processed 680/14806 books...
#    Processed 690/14806 books...
#    Processed 700/14806 books...
#    Processed 710/14806 books...
#    Processed 720/14806 books...
#    Processed 730/14806 books...
#    Processed 740/14806 books...
#    Processed 750/14806 books...
#    Processed 760/14806 books...
#    Processed 770/14806 books...
#    Processed 780/14806 books...
#    Processed 790/14806 books...
#    Processed 800/14806 books...
#    Processed 810/14806 books...
#    Processed 820/14806 books...
#    Processed 830/14806 books...
#    Processed 840/14806 books...
#    Processed 850/14806 books...
#    Processed 860/14806 books...
#    Processed 870/14806 books...
#    Processed 880/14806 books...
#    Processed 890/14806 books...
#    Processed 900/14806 books...
#    Processed 910/14806 books...
#    Processed 920/14806 books...
#    Processed 930/14806 books...
#    Processed 940/14806 books...
#    Processed 950/14806 books...
#    Processed 960/14806 books...
#    Processed 970/14806 books...
#    Processed 980/14806 books...
#    Processed 990/14806 books...
#    Processed 1000/14806 books...
#    Processed 1010/14806 books...
#    Processed 1020/14806 books...
#    Processed 1030/14806 books...
#    Processed 1040/14806 books...
#    Processed 1050/14806 books...
#    Processed 1060/14806 books...
#    Processed 1070/14806 books...
#    Processed 1080/14806 books...
#    Processed 1090/14806 books...
#    Processed 1100/14806 books...
#    Processed 1110/14806 books...
#    Processed 1120/14806 books...
#    Processed 1130/14806 books...
#    Processed 1140/14806 books...
#    Processed 1150/14806 books...
#    Processed 1160/14806 books...
#    Processed 1170/14806 books...
#    Processed 1180/14806 books...
#    Processed 1190/14806 books...
#    Processed 1200/14806 books...
#    Processed 1210/14806 books...
#    Processed 1220/14806 books...
#    Processed 1230/14806 books...
#    Processed 1240/14806 books...
#    Processed 1250/14806 books...
#    Processed 1260/14806 books...
#    Processed 1270/14806 books...
#    Processed 1280/14806 books...
#    Processed 1290/14806 books...
#    Processed 1300/14806 books...
#    Processed 1310/14806 books...
#    Processed 1320/14806 books...
#    Processed 1330/14806 books...
#    Processed 1340/14806 books...
#    Processed 1350/14806 books...
#    Processed 1360/14806 books...
#    Processed 1370/14806 books...
#    Processed 1380/14806 books...
#    Processed 1390/14806 books...
#    Processed 1400/14806 books...
#    Processed 1410/14806 books...
#    Processed 1420/14806 books...
#    Processed 1430/14806 books...
#    Processed 1440/14806 books...
#    Processed 1450/14806 books...
#    Processed 1460/14806 books...
#    Processed 1470/14806 books...
#    Processed 1480/14806 books...
#    Processed 1490/14806 books...
#    Processed 1500/14806 books...
#    Processed 1510/14806 books...
#    Processed 1520/14806 books...
#    Processed 1530/14806 books...
#    Processed 1540/14806 books...
#    Processed 1550/14806 books...
#    Processed 1560/14806 books...
#    Processed 1570/14806 books...
#    Processed 1580/14806 books...
#    Processed 1590/14806 books...
#    Processed 1600/14806 books...
#    Processed 1610/14806 books...
#    Processed 1620/14806 books...
#    Processed 1630/14806 books...
#    Processed 1640/14806 books...
#    Processed 1650/14806 books...
#    Processed 1660/14806 books...
#    Processed 1670/14806 books...
#    Processed 1680/14806 books...
#    Processed 1690/14806 books...
#    Processed 1700/14806 books...
#    Processed 1710/14806 books...
#    Processed 1720/14806 books...
#    Processed 1730/14806 books...
#    Processed 1740/14806 books...
#    Processed 1750/14806 books...
#    Processed 1760/14806 books...
#    Processed 1770/14806 books...
#    Processed 1780/14806 books...
#    Processed 1790/14806 books...
#    Processed 1800/14806 books...
#    Processed 1810/14806 books...
#    Processed 1820/14806 books...
#    Processed 1830/14806 books...
#    Processed 1840/14806 books...
#    Processed 1850/14806 books...
#    Processed 1860/14806 books...
#    Processed 1870/14806 books...
#    Processed 1880/14806 books...
#    Processed 1890/14806 books...
#    Processed 1900/14806 books...
#    Processed 1910/14806 books...
#    Processed 1920/14806 books...
#    Processed 1930/14806 books...
#    Processed 1940/14806 books...
#    Processed 1950/14806 books...
#    Processed 1960/14806 books...
#    Processed 1970/14806 books...
#    Processed 1980/14806 books...
#    Processed 1990/14806 books...
#    Processed 2000/14806 books...
#    Processed 2010/14806 books...
#    Processed 2020/14806 books...
#    Processed 2030/14806 books...
#    Processed 2040/14806 books...
#    Processed 2050/14806 books...
#    Processed 2060/14806 books...
#    Processed 2070/14806 books...
#    Processed 2080/14806 books...
#    Processed 2090/14806 books...
#    Processed 2100/14806 books...
#    Processed 2110/14806 books...
#    Processed 2120/14806 books...
#    Processed 2130/14806 books...
#    Processed 2140/14806 books...
#    Processed 2150/14806 books...
#    Processed 2160/14806 books...
#    Processed 2170/14806 books...
#    Processed 2180/14806 books...
#    Processed 2190/14806 books...
#    Processed 2200/14806 books...
#    Processed 2210/14806 books...
#    Processed 2220/14806 books...
#    Processed 2230/14806 books...
#    Processed 2240/14806 books...
#    Processed 2250/14806 books...
#    Processed 2260/14806 books...
#    Processed 2270/14806 books...
#    Processed 2280/14806 books...
#    Processed 2290/14806 books...
#    Processed 2300/14806 books...
#    Processed 2310/14806 books...
#    Processed 2320/14806 books...
#    Processed 2330/14806 books...
#    Processed 2340/14806 books...
#    Processed 2350/14806 books...
#    Processed 2360/14806 books...
#    Processed 2370/14806 books...
#    Processed 2380/14806 books...
#    Processed 2390/14806 books...
#    Processed 2400/14806 books...
#    Processed 2410/14806 books...
#    Processed 2420/14806 books...
#    Processed 2430/14806 books...
#    Processed 2440/14806 books...
#    Processed 2450/14806 books...
#    Processed 2460/14806 books...
#    Processed 2470/14806 books...
#    Processed 2480/14806 books...
#    Processed 2490/14806 books...
#    Processed 2500/14806 books...
#    Processed 2510/14806 books...
#    Processed 2520/14806 books...
#    Processed 2530/14806 books...
#    Processed 2540/14806 books...
#    Processed 2550/14806 books...
#    Processed 2560/14806 books...
#    Processed 2570/14806 books...
#    Processed 2580/14806 books...
#    Processed 2590/14806 books...
#    Processed 2600/14806 books...
#    Processed 2610/14806 books...
#    Processed 2620/14806 books...
#    Processed 2630/14806 books...
#    Processed 2640/14806 books...
#    Processed 2650/14806 books...
#    Processed 2660/14806 books...
#    Processed 2670/14806 books...
#    Processed 2680/14806 books...
#    Processed 2690/14806 books...
#    Processed 2700/14806 books...
#    Processed 2710/14806 books...
#    Processed 2720/14806 books...
#    Processed 2730/14806 books...
#    Processed 2740/14806 books...
#    Processed 2750/14806 books...
#    Processed 2760/14806 books...
#    Processed 2770/14806 books...
#    Processed 2780/14806 books...
#    Processed 2790/14806 books...
#    Processed 2800/14806 books...
#    Processed 2810/14806 books...
#    Processed 2820/14806 books...
#    Processed 2830/14806 books...
#    Processed 2840/14806 books...
#    Processed 2850/14806 books...
#    Processed 2860/14806 books...
#    Processed 2870/14806 books...
#    Processed 2880/14806 books...
#    Processed 2890/14806 books...
#    Processed 2900/14806 books...
#    Processed 2910/14806 books...
#    Processed 2920/14806 books...
#    Processed 2930/14806 books...
#    Processed 2940/14806 books...
#    Processed 2950/14806 books...
#    Processed 2960/14806 books...
#    Processed 2970/14806 books...
#    Processed 2980/14806 books...
#    Processed 2990/14806 books...
#    Processed 3000/14806 books...
#    Processed 3010/14806 books...
#    Processed 3020/14806 books...
#    Processed 3030/14806 books...
#    Processed 3040/14806 books...
#    Processed 3050/14806 books...
#    Processed 3060/14806 books...
#    Processed 3070/14806 books...
#    Processed 3080/14806 books...
#    Processed 3090/14806 books...
#    Processed 3100/14806 books...
#    Processed 3110/14806 books...
#    Processed 3120/14806 books...
#    Processed 3130/14806 books...
#    Processed 3140/14806 books...
#    Processed 3150/14806 books...
#    Processed 3160/14806 books...
#    Processed 3170/14806 books...
#    Processed 3180/14806 books...
#    Processed 3190/14806 books...
#    Processed 3200/14806 books...
#    Processed 3210/14806 books...
#    Processed 3220/14806 books...
#    Processed 3230/14806 books...
#    Processed 3240/14806 books...
#    Processed 3250/14806 books...
#    Processed 3260/14806 books...
#    Processed 3270/14806 books...
#    Processed 3280/14806 books...
#    Processed 3290/14806 books...
#    Processed 3300/14806 books...
#    Processed 3310/14806 books...
#    Processed 3320/14806 books...
#    Processed 3330/14806 books...
#    Processed 3340/14806 books...
#    Processed 3350/14806 books...
#    Processed 3360/14806 books...
#    Processed 3370/14806 books...
#    Processed 3380/14806 books...
#    Processed 3390/14806 books...
#    Processed 3400/14806 books...
#    Processed 3410/14806 books...
#    Processed 3420/14806 books...
#    Processed 3430/14806 books...
#    Processed 3440/14806 books...
#    Processed 3450/14806 books...
#    Processed 3460/14806 books...
#    Processed 3470/14806 books...
#    Processed 3480/14806 books...
#    Processed 3490/14806 books...
#    Processed 3500/14806 books...
#    Processed 3510/14806 books...
#    Processed 3520/14806 books...
#    Processed 3530/14806 books...
#    Processed 3540/14806 books...
#    Processed 3550/14806 books...
#    Processed 3560/14806 books...
#    Processed 3570/14806 books...
#    Processed 3580/14806 books...
#    Processed 3590/14806 books...
#    Processed 3600/14806 books...
#    Processed 3610/14806 books...
#    Processed 3620/14806 books...
#    Processed 3630/14806 books...
#    Processed 3640/14806 books...
#    Processed 3650/14806 books...
#    Processed 3660/14806 books...
#    Processed 3670/14806 books...
#    Processed 3680/14806 books...
#    Processed 3690/14806 books...
#    Processed 3700/14806 books...
#    Processed 3710/14806 books...
#    Processed 3720/14806 books...
#    Processed 3730/14806 books...
#    Processed 3740/14806 books...
#    Processed 3750/14806 books...
#    Processed 3760/14806 books...
#    Processed 3770/14806 books...
#    Processed 3780/14806 books...
#    Processed 3790/14806 books...
#    Processed 3800/14806 books...
#    Processed 3810/14806 books...
#    Processed 3820/14806 books...
#    Processed 3830/14806 books...
#    Processed 3840/14806 books...
#    Processed 3850/14806 books...
#    Processed 3860/14806 books...
#    Processed 3870/14806 books...
#    Processed 3880/14806 books...
#    Processed 3890/14806 books...
#    Processed 3900/14806 books...
#    Processed 3910/14806 books...
#    Processed 3920/14806 books...
#    Processed 3930/14806 books...
#    Processed 3940/14806 books...
#    Processed 3950/14806 books...
#    Processed 3960/14806 books...
#    Processed 3970/14806 books...
#    Processed 3980/14806 books...
#    Processed 3990/14806 books...
#    Processed 4000/14806 books...
#    Processed 4010/14806 books...
#    Processed 4020/14806 books...
#    Processed 4030/14806 books...
#    Processed 4040/14806 books...
#    Processed 4050/14806 books...
#    Processed 4060/14806 books...
#    Processed 4070/14806 books...
#    Processed 4080/14806 books...
#    Processed 4090/14806 books...
#    Processed 4100/14806 books...
#    Processed 4110/14806 books...
#    Processed 4120/14806 books...
#    Processed 4130/14806 books...
#    Processed 4140/14806 books...
#    Processed 4150/14806 books...
#    Processed 4160/14806 books...
#    Processed 4170/14806 books...
#    Processed 4180/14806 books...
#    Processed 4190/14806 books...
#    Processed 4200/14806 books...
#    Processed 4210/14806 books...
#    Processed 4220/14806 books...
#    Processed 4230/14806 books...
#    Processed 4240/14806 books...
#    Processed 4250/14806 books...
#    Processed 4260/14806 books...
#    Processed 4270/14806 books...
#    Processed 4280/14806 books...
#    Processed 4290/14806 books...
#    Processed 4300/14806 books...
#    Processed 4310/14806 books...
#    Processed 4320/14806 books...
#    Processed 4330/14806 books...
#    Processed 4340/14806 books...
#    Processed 4350/14806 books...
#    Processed 4360/14806 books...
#    Processed 4370/14806 books...
#    Processed 4380/14806 books...
#    Processed 4390/14806 books...
#    Processed 4400/14806 books...
#    Processed 4410/14806 books...
#    Processed 4420/14806 books...
#    Processed 4430/14806 books...
#    Processed 4440/14806 books...
#    Processed 4450/14806 books...
#    Processed 4460/14806 books...
#    Processed 4470/14806 books...
#    Processed 4480/14806 books...
#    Processed 4490/14806 books...
#    Processed 4500/14806 books...
#    Processed 4510/14806 books...
#    Processed 4520/14806 books...
#    Processed 4530/14806 books...
#    Processed 4540/14806 books...
#    Processed 4550/14806 books...
#    Processed 4560/14806 books...
#    Processed 4570/14806 books...
#    Processed 4580/14806 books...
#    Processed 4590/14806 books...
#    Processed 4600/14806 books...
#    Processed 4610/14806 books...
#    Processed 4620/14806 books...
#    Processed 4630/14806 books...
#    Processed 4640/14806 books...
#    Processed 4650/14806 books...
#    Processed 4660/14806 books...
#    Processed 4670/14806 books...
#    Processed 4680/14806 books...
#    Processed 4690/14806 books...
#    Processed 4700/14806 books...
#    Processed 4710/14806 books...
#    Processed 4720/14806 books...
#    Processed 4730/14806 books...
#    Processed 4740/14806 books...
#    Processed 4750/14806 books...
#    Processed 4760/14806 books...
#    Processed 4770/14806 books...
#    Processed 4780/14806 books...
#    Processed 4790/14806 books...
#    Processed 4800/14806 books...
#    Processed 4810/14806 books...
#    Processed 4820/14806 books...
#    Processed 4830/14806 books...
#    Processed 4840/14806 books...
#    Processed 4850/14806 books...
#    Processed 4860/14806 books...
#    Processed 4870/14806 books...
#    Processed 4880/14806 books...
#    Processed 4890/14806 books...
#    Processed 4900/14806 books...
#    Processed 4910/14806 books...
#    Processed 4920/14806 books...
#    Processed 4930/14806 books...
#    Processed 4940/14806 books...
#    Processed 4950/14806 books...
#    Processed 4960/14806 books...
#    Processed 4970/14806 books...
#    Processed 4980/14806 books...
#    Processed 4990/14806 books...
#    Processed 5000/14806 books...
#    Processed 5010/14806 books...
#    Processed 5020/14806 books...
#    Processed 5030/14806 books...
#    Processed 5040/14806 books...
#    Processed 5050/14806 books...
#    Processed 5060/14806 books...
#    Processed 5070/14806 books...
#    Processed 5080/14806 books...
#    Processed 5090/14806 books...
#    Processed 5100/14806 books...
#    Processed 5110/14806 books...
#    Processed 5120/14806 books...
#    Processed 5130/14806 books...
#    Processed 5140/14806 books...
#    Processed 5150/14806 books...
#    Processed 5160/14806 books...
#    Processed 5170/14806 books...
#    Processed 5180/14806 books...
#    Processed 5190/14806 books...
#    Processed 5200/14806 books...
#    Processed 5210/14806 books...
#    Processed 5220/14806 books...
#    Processed 5230/14806 books...
#    Processed 5240/14806 books...
#    Processed 5250/14806 books...
#    Processed 5260/14806 books...
#    Processed 5270/14806 books...
#    Processed 5280/14806 books...
#    Processed 5290/14806 books...
#    Processed 5300/14806 books...
#    Processed 5310/14806 books...
#    Processed 5320/14806 books...
#    Processed 5330/14806 books...
#    Processed 5340/14806 books...
#    Processed 5350/14806 books...
#    Processed 5360/14806 books...
#    Processed 5370/14806 books...
#    Processed 5380/14806 books...
#    Processed 5390/14806 books...
#    Processed 5400/14806 books...
#    Processed 5410/14806 books...
#    Processed 5420/14806 books...
#    Processed 5430/14806 books...
#    Processed 5440/14806 books...
#    Processed 5450/14806 books...
#    Processed 5460/14806 books...
#    Processed 5470/14806 books...
#    Processed 5480/14806 books...
#    Processed 5490/14806 books...
#    Processed 5500/14806 books...
#    Processed 5510/14806 books...
#    Processed 5520/14806 books...
#    Processed 5530/14806 books...
#    Processed 5540/14806 books...
#    Processed 5550/14806 books...
#    Processed 5560/14806 books...
#    Processed 5570/14806 books...
#    Processed 5580/14806 books...
#    Processed 5590/14806 books...
#    Processed 5600/14806 books...
#    Processed 5610/14806 books...
#    Processed 5620/14806 books...
#    Processed 5630/14806 books...
#    Processed 5640/14806 books...
#    Processed 5650/14806 books...
#    Processed 5660/14806 books...
#    Processed 5670/14806 books...
#    Processed 5680/14806 books...
#    Processed 5690/14806 books...
#    Processed 5700/14806 books...
#    Processed 5710/14806 books...
#    Processed 5720/14806 books...
#    Processed 5730/14806 books...
#    Processed 5740/14806 books...
#    Processed 5750/14806 books...
#    Processed 5760/14806 books...
#    Processed 5770/14806 books...
#    Processed 5780/14806 books...
#    Processed 5790/14806 books...
#    Processed 5800/14806 books...
#    Processed 5810/14806 books...
#    Processed 5820/14806 books...
#    Processed 5830/14806 books...
#    Processed 5840/14806 books...
#    Processed 5850/14806 books...
#    Processed 5860/14806 books...
#    Processed 5870/14806 books...
#    Processed 5880/14806 books...
#    Processed 5890/14806 books...
#    Processed 5900/14806 books...
#    Processed 5910/14806 books...
#    Processed 5920/14806 books...
#    Processed 5930/14806 books...
#    Processed 5940/14806 books...
#    Processed 5950/14806 books...
#    Processed 5960/14806 books...
#    Processed 5970/14806 books...
#    Processed 5980/14806 books...
#    Processed 5990/14806 books...
#    Processed 6000/14806 books...
#    Processed 6010/14806 books...
#    Processed 6020/14806 books...
#    Processed 6030/14806 books...
#    Processed 6040/14806 books...
#    Processed 6050/14806 books...
#    Processed 6060/14806 books...
#    Processed 6070/14806 books...
#    Processed 6080/14806 books...
#    Processed 6090/14806 books...
#    Processed 6100/14806 books...
#    Processed 6110/14806 books...
#    Processed 6120/14806 books...
#    Processed 6130/14806 books...
#    Processed 6140/14806 books...
#    Processed 6150/14806 books...
#    Processed 6160/14806 books...
#    Processed 6170/14806 books...
#    Processed 6180/14806 books...
#    Processed 6190/14806 books...
#    Processed 6200/14806 books...
#    Processed 6210/14806 books...
#    Processed 6220/14806 books...
#    Processed 6230/14806 books...
#    Processed 6240/14806 books...
#    Processed 6250/14806 books...
#    Processed 6260/14806 books...
#    Processed 6270/14806 books...
#    Processed 6280/14806 books...
#    Processed 6290/14806 books...
#    Processed 6300/14806 books...
#    Processed 6310/14806 books...
#    Processed 6320/14806 books...
#    Processed 6330/14806 books...
#    Processed 6340/14806 books...
#    Processed 6350/14806 books...
#    Processed 6360/14806 books...
#    Processed 6370/14806 books...
#    Processed 6380/14806 books...
#    Processed 6390/14806 books...
#    Processed 6400/14806 books...
#    Processed 6410/14806 books...
#    Processed 6420/14806 books...
#    Processed 6430/14806 books...
#    Processed 6440/14806 books...
#    Processed 6450/14806 books...
#    Processed 6460/14806 books...
#    Processed 6470/14806 books...
#    Processed 6480/14806 books...
#    Processed 6490/14806 books...
#    Processed 6500/14806 books...
#    Processed 6510/14806 books...
#    Processed 6520/14806 books...
#    Processed 6530/14806 books...
#    Processed 6540/14806 books...
#    Processed 6550/14806 books...
#    Processed 6560/14806 books...
#    Processed 6570/14806 books...
#    Processed 6580/14806 books...
#    Processed 6590/14806 books...
#    Processed 6600/14806 books...
#    Processed 6610/14806 books...
#    Processed 6620/14806 books...
#    Processed 6630/14806 books...
#    Processed 6640/14806 books...
#    Processed 6650/14806 books...
#    Processed 6660/14806 books...
#    Processed 6670/14806 books...
#    Processed 6680/14806 books...
#    Processed 6690/14806 books...
#    Processed 6700/14806 books...
#    Processed 6710/14806 books...
#    Processed 6720/14806 books...
#    Processed 6730/14806 books...
#    Processed 6740/14806 books...
#    Processed 6750/14806 books...
#    Processed 6760/14806 books...
#    Processed 6770/14806 books...
#    Processed 6780/14806 books...
#    Processed 6790/14806 books...
#    Processed 6800/14806 books...
#    Processed 6810/14806 books...
#    Processed 6820/14806 books...
#    Processed 6830/14806 books...
#    Processed 6840/14806 books...
#    Processed 6850/14806 books...
#    Processed 6860/14806 books...
#    Processed 6870/14806 books...
#    Processed 6880/14806 books...
#    Processed 6890/14806 books...
#    Processed 6900/14806 books...
#    Processed 6910/14806 books...
#    Processed 6920/14806 books...
#    Processed 6930/14806 books...
#    Processed 6940/14806 books...
#    Processed 6950/14806 books...
#    Processed 6960/14806 books...
#    Processed 6970/14806 books...
#    Processed 6980/14806 books...
#    Processed 6990/14806 books...
#    Processed 7000/14806 books...
#    Processed 7010/14806 books...
#    Processed 7020/14806 books...
#    Processed 7030/14806 books...
#    Processed 7040/14806 books...
#    Processed 7050/14806 books...
#    Processed 7060/14806 books...
#    Processed 7070/14806 books...
#    Processed 7080/14806 books...
#    Processed 7090/14806 books...
#    Processed 7100/14806 books...
#    Processed 7110/14806 books...
#    Processed 7120/14806 books...
#    Processed 7130/14806 books...
#    Processed 7140/14806 books...
#    Processed 7150/14806 books...
#    Processed 7160/14806 books...
#    Processed 7170/14806 books...
#    Processed 7180/14806 books...
#    Processed 7190/14806 books...
#    Processed 7200/14806 books...
#    Processed 7210/14806 books...
#    Processed 7220/14806 books...
#    Processed 7230/14806 books...
#    Processed 7240/14806 books...
#    Processed 7250/14806 books...
#    Processed 7260/14806 books...
#    Processed 7270/14806 books...
#    Processed 7280/14806 books...
#    Processed 7290/14806 books...
#    Processed 7300/14806 books...
#    Processed 7310/14806 books...
#    Processed 7320/14806 books...
#    Processed 7330/14806 books...
#    Processed 7340/14806 books...
#    Processed 7350/14806 books...
#    Processed 7360/14806 books...
#    Processed 7370/14806 books...
#    Processed 7380/14806 books...
#    Processed 7390/14806 books...
#    Processed 7400/14806 books...
#    Processed 7410/14806 books...
#    Processed 7420/14806 books...
#    Processed 7430/14806 books...
#    Processed 7440/14806 books...
#    Processed 7450/14806 books...
#    Processed 7460/14806 books...
#    Processed 7470/14806 books...
#    Processed 7480/14806 books...
#    Processed 7490/14806 books...
#    Processed 7500/14806 books...
#    Processed 7510/14806 books...
#    Processed 7520/14806 books...
#    Processed 7530/14806 books...
#    Processed 7540/14806 books...
#    Processed 7550/14806 books...
#    Processed 7560/14806 books...
#    Processed 7570/14806 books...
#    Processed 7580/14806 books...
#    Processed 7590/14806 books...
#    Processed 7600/14806 books...
#    Processed 7610/14806 books...
#    Processed 7620/14806 books...
#    Processed 7630/14806 books...
#    Processed 7640/14806 books...
#    Processed 7650/14806 books...
#    Processed 7660/14806 books...
#    Processed 7670/14806 books...
#    Processed 7680/14806 books...
#    Processed 7690/14806 books...
#    Processed 7700/14806 books...
#    Processed 7710/14806 books...
#    Processed 7720/14806 books...
#    Processed 7730/14806 books...
#    Processed 7740/14806 books...
#    Processed 7750/14806 books...
#    Processed 7760/14806 books...
#    Processed 7770/14806 books...
#    Processed 7780/14806 books...
#    Processed 7790/14806 books...
#    Processed 7800/14806 books...
#    Processed 7810/14806 books...
#    Processed 7820/14806 books...
#    Processed 7830/14806 books...
#    Processed 7840/14806 books...
#    Processed 7850/14806 books...
#    Processed 7860/14806 books...
#    Processed 7870/14806 books...
#    Processed 7880/14806 books...
#    Processed 7890/14806 books...
#    Processed 7900/14806 books...
#    Processed 7910/14806 books...
#    Processed 7920/14806 books...
#    Processed 7930/14806 books...
#    Processed 7940/14806 books...
#    Processed 7950/14806 books...
#    Processed 7960/14806 books...
#    Processed 7970/14806 books...
#    Processed 7980/14806 books...
#    Processed 7990/14806 books...
#    Processed 8000/14806 books...
#    Processed 8010/14806 books...
#    Processed 8020/14806 books...
#    Processed 8030/14806 books...
#    Processed 8040/14806 books...
#    Processed 8050/14806 books...
#    Processed 8060/14806 books...
#    Processed 8070/14806 books...
#    Processed 8080/14806 books...
#    Processed 8090/14806 books...
#    Processed 8100/14806 books...
#    Processed 8110/14806 books...
#    Processed 8120/14806 books...
#    Processed 8130/14806 books...
#    Processed 8140/14806 books...
#    Processed 8150/14806 books...
#    Processed 8160/14806 books...
#    Processed 8170/14806 books...
#    Processed 8180/14806 books...
#    Processed 8190/14806 books...
#    Processed 8200/14806 books...
#    Processed 8210/14806 books...
#    Processed 8220/14806 books...
#    Processed 8230/14806 books...
#    Processed 8240/14806 books...
#    Processed 8250/14806 books...
#    Processed 8260/14806 books...
#    Processed 8270/14806 books...
#    Processed 8280/14806 books...
#    Processed 8290/14806 books...
#    Processed 8300/14806 books...
#    Processed 8310/14806 books...
#    Processed 8320/14806 books...
#    Processed 8330/14806 books...
#    Processed 8340/14806 books...
#    Processed 8350/14806 books...
#    Processed 8360/14806 books...
#    Processed 8370/14806 books...
#    Processed 8380/14806 books...
#    Processed 8390/14806 books...
#    Processed 8400/14806 books...
#    Processed 8410/14806 books...
#    Processed 8420/14806 books...
#    Processed 8430/14806 books...
#    Processed 8440/14806 books...
#    Processed 8450/14806 books...
#    Processed 8460/14806 books...
#    Processed 8470/14806 books...
#    Processed 8480/14806 books...
#    Processed 8490/14806 books...
#    Processed 8500/14806 books...
#    Processed 8510/14806 books...
#    Processed 8520/14806 books...
#    Processed 8530/14806 books...
#    Processed 8540/14806 books...
#    Processed 8550/14806 books...
#    Processed 8560/14806 books...
#    Processed 8570/14806 books...
#    Processed 8580/14806 books...
#    Processed 8590/14806 books...
#    Processed 8600/14806 books...
#    Processed 8610/14806 books...
#    Processed 8620/14806 books...
#    Processed 8630/14806 books...
#    Processed 8640/14806 books...
#    Processed 8650/14806 books...
#    Processed 8660/14806 books...
#    Processed 8670/14806 books...
#    Processed 8680/14806 books...
#    Processed 8690/14806 books...
#    Processed 8700/14806 books...
#    Processed 8710/14806 books...
#    Processed 8720/14806 books...
#    Processed 8730/14806 books...
#    Processed 8740/14806 books...
#    Processed 8750/14806 books...
#    Processed 8760/14806 books...
#    Processed 8770/14806 books...
#    Processed 8780/14806 books...
#    Processed 8790/14806 books...
#    Processed 8800/14806 books...
#    Processed 8810/14806 books...
#    Processed 8820/14806 books...
#    Processed 8830/14806 books...
#    Processed 8840/14806 books...
#    Processed 8850/14806 books...
#    Processed 8860/14806 books...
#    Processed 8870/14806 books...
#    Processed 8880/14806 books...
#    Processed 8890/14806 books...
#    Processed 8900/14806 books...
#    Processed 8910/14806 books...
#    Processed 8920/14806 books...
#    Processed 8930/14806 books...
#    Processed 8940/14806 books...
#    Processed 8950/14806 books...
#    Processed 8960/14806 books...
#    Processed 8970/14806 books...
#    Processed 8980/14806 books...
#    Processed 8990/14806 books...
#    Processed 9000/14806 books...
#    Processed 9010/14806 books...
#    Processed 9020/14806 books...
#    Processed 9030/14806 books...
#    Processed 9040/14806 books...
#    Processed 9050/14806 books...
#    Processed 9060/14806 books...
#    Processed 9070/14806 books...
#    Processed 9080/14806 books...
#    Processed 9090/14806 books...
#    Processed 9100/14806 books...
#    Processed 9110/14806 books...
#    Processed 9120/14806 books...
#    Processed 9130/14806 books...
#    Processed 9140/14806 books...
#    Processed 9150/14806 books...
#    Processed 9160/14806 books...
#    Processed 9170/14806 books...
#    Processed 9180/14806 books...
#    Processed 9190/14806 books...
#    Processed 9200/14806 books...
#    Processed 9210/14806 books...
#    Processed 9220/14806 books...
#    Processed 9230/14806 books...
#    Processed 9240/14806 books...
#    Processed 9250/14806 books...
#    Processed 9260/14806 books...
#    Processed 9270/14806 books...
#    Processed 9280/14806 books...
#    Processed 9290/14806 books...
#    Processed 9300/14806 books...
#    Processed 9310/14806 books...
#    Processed 9320/14806 books...
#    Processed 9330/14806 books...
#    Processed 9340/14806 books...
#    Processed 9350/14806 books...
#    Processed 9360/14806 books...
#    Processed 9370/14806 books...
#    Processed 9380/14806 books...
#    Processed 9390/14806 books...
#    Processed 9400/14806 books...
#    Processed 9410/14806 books...
#    Processed 9420/14806 books...
#    Processed 9430/14806 books...
#    Processed 9440/14806 books...
#    Processed 9450/14806 books...
#    Processed 9460/14806 books...
#    Processed 9470/14806 books...
#    Processed 9480/14806 books...
#    Processed 9490/14806 books...
#    Processed 9500/14806 books...
#    Processed 9510/14806 books...
#    Processed 9520/14806 books...
#    Processed 9530/14806 books...
#    Processed 9540/14806 books...
#    Processed 9550/14806 books...
#    Processed 9560/14806 books...
#    Processed 9570/14806 books...
#    Processed 9580/14806 books...
#    Processed 9590/14806 books...
#    Processed 9600/14806 books...
#    Processed 9610/14806 books...
#    Processed 9620/14806 books...
#    Processed 9630/14806 books...
#    Processed 9640/14806 books...
#    Processed 9650/14806 books...
#    Processed 9660/14806 books...
#    Processed 9670/14806 books...
#    Processed 9680/14806 books...
#    Processed 9690/14806 books...
#    Processed 9700/14806 books...
#    Processed 9710/14806 books...
#    Processed 9720/14806 books...
#    Processed 9730/14806 books...
#    Processed 9740/14806 books...
#    Processed 9750/14806 books...
#    Processed 9760/14806 books...
#    Processed 9770/14806 books...
#    Processed 9780/14806 books...
#    Processed 9790/14806 books...
#    Processed 9800/14806 books...
#    Processed 9810/14806 books...
#    Processed 9820/14806 books...
#    Processed 9830/14806 books...
#    Processed 9840/14806 books...
#    Processed 9850/14806 books...
#    Processed 9860/14806 books...
#    Processed 9870/14806 books...
#    Processed 9880/14806 books...
#    Processed 9890/14806 books...
#    Processed 9900/14806 books...
#    Processed 9910/14806 books...
#    Processed 9920/14806 books...
#    Processed 9930/14806 books...
#    Processed 9940/14806 books...
#    Processed 9950/14806 books...
#    Processed 9960/14806 books...
#    Processed 9970/14806 books...
#    Processed 9980/14806 books...
#    Processed 9990/14806 books...
#    Processed 10000/14806 books...
#    Processed 10010/14806 books...
#    Processed 10020/14806 books...
#    Processed 10030/14806 books...
#    Processed 10040/14806 books...
#    Processed 10050/14806 books...
#    Processed 10060/14806 books...
#    Processed 10070/14806 books...
#    Processed 10080/14806 books...
#    Processed 10090/14806 books...
#    Processed 10100/14806 books...
#    Processed 10110/14806 books...
#    Processed 10120/14806 books...
#    Processed 10130/14806 books...
#    Processed 10140/14806 books...
#    Processed 10150/14806 books...
#    Processed 10160/14806 books...
#    Processed 10170/14806 books...
#    Processed 10180/14806 books...
#    Processed 10190/14806 books...
#    Processed 10200/14806 books...
#    Processed 10210/14806 books...
#    Processed 10220/14806 books...
#    Processed 10230/14806 books...
#    Processed 10240/14806 books...
#    Processed 10250/14806 books...
#    Processed 10260/14806 books...
#    Processed 10270/14806 books...
#    Processed 10280/14806 books...
#    Processed 10290/14806 books...
#    Processed 10300/14806 books...
#    Processed 10310/14806 books...
#    Processed 10320/14806 books...
#    Processed 10330/14806 books...
#    Processed 10340/14806 books...
#    Processed 10350/14806 books...
#    Processed 10360/14806 books...
#    Processed 10370/14806 books...
#    Processed 10380/14806 books...
#    Processed 10390/14806 books...
#    Processed 10400/14806 books...
#    Processed 10410/14806 books...
#    Processed 10420/14806 books...
#    Processed 10430/14806 books...
#    Processed 10440/14806 books...
#    Processed 10450/14806 books...
#    Processed 10460/14806 books...
#    Processed 10470/14806 books...
#    Processed 10480/14806 books...
#    Processed 10490/14806 books...
#    Processed 10500/14806 books...
#    Processed 10510/14806 books...
#    Processed 10520/14806 books...
#    Processed 10530/14806 books...
#    Processed 10540/14806 books...
#    Processed 10550/14806 books...
#    Processed 10560/14806 books...
#    Processed 10570/14806 books...
#    Processed 10580/14806 books...
#    Processed 10590/14806 books...
#    Processed 10600/14806 books...
#    Processed 10610/14806 books...
#    Processed 10620/14806 books...
#    Processed 10630/14806 books...
#    Processed 10640/14806 books...
#    Processed 10650/14806 books...
#    Processed 10660/14806 books...
#    Processed 10670/14806 books...
#    Processed 10680/14806 books...
#    Processed 10690/14806 books...
#    Processed 10700/14806 books...
#    Processed 10710/14806 books...
#    Processed 10720/14806 books...
#    Processed 10730/14806 books...
#    Processed 10740/14806 books...
#    Processed 10750/14806 books...
#    Processed 10760/14806 books...
#    Processed 10770/14806 books...
#    Processed 10780/14806 books...
#    Processed 10790/14806 books...
#    Processed 10800/14806 books...
#    Processed 10810/14806 books...
#    Processed 10820/14806 books...
#    Processed 10830/14806 books...
#    Processed 10840/14806 books...
#    Processed 10850/14806 books...
#    Processed 10860/14806 books...
#    Processed 10870/14806 books...
#    Processed 10880/14806 books...
#    Processed 10890/14806 books...
#    Processed 10900/14806 books...
#    Processed 10910/14806 books...
#    Processed 10920/14806 books...
#    Processed 10930/14806 books...
#    Processed 10940/14806 books...
#    Processed 10950/14806 books...
#    Processed 10960/14806 books...
#    Processed 10970/14806 books...
#    Processed 10980/14806 books...
#    Processed 10990/14806 books...
#    Processed 11000/14806 books...
#    Processed 11010/14806 books...
#    Processed 11020/14806 books...
#    Processed 11030/14806 books...
#    Processed 11040/14806 books...
#    Processed 11050/14806 books...
#    Processed 11060/14806 books...
#    Processed 11070/14806 books...
#    Processed 11080/14806 books...
#    Processed 11090/14806 books...
#    Processed 11100/14806 books...
#    Processed 11110/14806 books...
#    Processed 11120/14806 books...
#    Processed 11130/14806 books...
#    Processed 11140/14806 books...
#    Processed 11150/14806 books...
#    Processed 11160/14806 books...
#    Processed 11170/14806 books...
#    Processed 11180/14806 books...
#    Processed 11190/14806 books...
#    Processed 11200/14806 books...
#    Processed 11210/14806 books...
#    Processed 11220/14806 books...
#    Processed 11230/14806 books...
#    Processed 11240/14806 books...
#    Processed 11250/14806 books...
#    Processed 11260/14806 books...
#    Processed 11270/14806 books...
#    Processed 11280/14806 books...
#    Processed 11290/14806 books...
#    Processed 11300/14806 books...
#    Processed 11310/14806 books...
#    Processed 11320/14806 books...
#    Processed 11330/14806 books...
#    Processed 11340/14806 books...
#    Processed 11350/14806 books...
#    Processed 11360/14806 books...
#    Processed 11370/14806 books...
#    Processed 11380/14806 books...
#    Processed 11390/14806 books...
#    Processed 11400/14806 books...
#    Processed 11410/14806 books...
#    Processed 11420/14806 books...
#    Processed 11430/14806 books...
#    Processed 11440/14806 books...
#    Processed 11450/14806 books...
#    Processed 11460/14806 books...
#    Processed 11470/14806 books...
#    Processed 11480/14806 books...
#    Processed 11490/14806 books...
#    Processed 11500/14806 books...
#    Processed 11510/14806 books...
#    Processed 11520/14806 books...
#    Processed 11530/14806 books...
#    Processed 11540/14806 books...
#    Processed 11550/14806 books...
#    Processed 11560/14806 books...
#    Processed 11570/14806 books...
#    Processed 11580/14806 books...
#    Processed 11590/14806 books...
#    Processed 11600/14806 books...
#    Processed 11610/14806 books...
#    Processed 11620/14806 books...
#    Processed 11630/14806 books...
#    Processed 11640/14806 books...
#    Processed 11650/14806 books...
#    Processed 11660/14806 books...
#    Processed 11670/14806 books...
#    Processed 11680/14806 books...
#    Processed 11690/14806 books...
#    Processed 11700/14806 books...
#    Processed 11710/14806 books...
#    Processed 11720/14806 books...
#    Processed 11730/14806 books...
#    Processed 11740/14806 books...
#    Processed 11750/14806 books...
#    Processed 11760/14806 books...
#    Processed 11770/14806 books...
#    Processed 11780/14806 books...
#    Processed 11790/14806 books...
#    Processed 11800/14806 books...
#    Processed 11810/14806 books...
#    Processed 11820/14806 books...
#    Processed 11830/14806 books...
#    Processed 11840/14806 books...
#    Processed 11850/14806 books...
#    Processed 11860/14806 books...
#    Processed 11870/14806 books...
#    Processed 11880/14806 books...
#    Processed 11890/14806 books...
#    Processed 11900/14806 books...
#    Processed 11910/14806 books...
#    Processed 11920/14806 books...
#    Processed 11930/14806 books...
#    Processed 11940/14806 books...
#    Processed 11950/14806 books...
#    Processed 11960/14806 books...
#    Processed 11970/14806 books...
#    Processed 11980/14806 books...
#    Processed 11990/14806 books...
#    Processed 12000/14806 books...
#    Processed 12010/14806 books...
#    Processed 12020/14806 books...
#    Processed 12030/14806 books...
#    Processed 12040/14806 books...
#    Processed 12050/14806 books...
#    Processed 12060/14806 books...
#    Processed 12070/14806 books...
#    Processed 12080/14806 books...
#    Processed 12090/14806 books...
#    Processed 12100/14806 books...
#    Processed 12110/14806 books...
#    Processed 12120/14806 books...
#    Processed 12130/14806 books...
#    Processed 12140/14806 books...
#    Processed 12150/14806 books...
#    Processed 12160/14806 books...
#    Processed 12170/14806 books...
#    Processed 12180/14806 books...
#    Processed 12190/14806 books...
#    Processed 12200/14806 books...
#    Processed 12210/14806 books...
#    Processed 12220/14806 books...
#    Processed 12230/14806 books...
#    Processed 12240/14806 books...
#    Processed 12250/14806 books...
#    Processed 12260/14806 books...
#    Processed 12270/14806 books...
#    Processed 12280/14806 books...
#    Processed 12290/14806 books...
#    Processed 12300/14806 books...
#    Processed 12310/14806 books...
#    Processed 12320/14806 books...
#    Processed 12330/14806 books...
#    Processed 12340/14806 books...
#    Processed 12350/14806 books...
#    Processed 12360/14806 books...
#    Processed 12370/14806 books...
#    Processed 12380/14806 books...
#    Processed 12390/14806 books...
#    Processed 12400/14806 books...
#    Processed 12410/14806 books...
#    Processed 12420/14806 books...
#    Processed 12430/14806 books...
#    Processed 12440/14806 books...
#    Processed 12450/14806 books...
#    Processed 12460/14806 books...
#    Processed 12470/14806 books...
#    Processed 12480/14806 books...
#    Processed 12490/14806 books...
#    Processed 12500/14806 books...
#    Processed 12510/14806 books...
#    Processed 12520/14806 books...
#    Processed 12530/14806 books...
#    Processed 12540/14806 books...
#    Processed 12550/14806 books...
#    Processed 12560/14806 books...
#    Processed 12570/14806 books...
#    Processed 12580/14806 books...
#    Processed 12590/14806 books...
#    Processed 12600/14806 books...
#    Processed 12610/14806 books...
#    Processed 12620/14806 books...
#    Processed 12630/14806 books...
#    Processed 12640/14806 books...
#    Processed 12650/14806 books...
#    Processed 12660/14806 books...
#    Processed 12670/14806 books...
#    Processed 12680/14806 books...
#    Processed 12690/14806 books...
#    Processed 12700/14806 books...
#    Processed 12710/14806 books...
#    Processed 12720/14806 books...
#    Processed 12730/14806 books...
#    Processed 12740/14806 books...
#    Processed 12750/14806 books...
#    Processed 12760/14806 books...
#    Processed 12770/14806 books...
#    Processed 12780/14806 books...
#    Processed 12790/14806 books...
#    Processed 12800/14806 books...
#    Processed 12810/14806 books...
#    Processed 12820/14806 books...
#    Processed 12830/14806 books...
#    Processed 12840/14806 books...
#    Processed 12850/14806 books...
#    Processed 12860/14806 books...
#    Processed 12870/14806 books...
#    Processed 12880/14806 books...
#    Processed 12890/14806 books...
#    Processed 12900/14806 books...
#    Processed 12910/14806 books...
#    Processed 12920/14806 books...
#    Processed 12930/14806 books...
#    Processed 12940/14806 books...
#    Processed 12950/14806 books...
#    Processed 12960/14806 books...
#    Processed 12970/14806 books...
#    Processed 12980/14806 books...
#    Processed 12990/14806 books...
#    Processed 13000/14806 books...
#    Processed 13010/14806 books...
#    Processed 13020/14806 books...
#    Processed 13030/14806 books...
#    Processed 13040/14806 books...
#    Processed 13050/14806 books...
#    Processed 13060/14806 books...
#    Processed 13070/14806 books...
#    Processed 13080/14806 books...
#    Processed 13090/14806 books...
#    Processed 13100/14806 books...
#    Processed 13110/14806 books...
#    Processed 13120/14806 books...
#    Processed 13130/14806 books...
#    Processed 13140/14806 books...
#    Processed 13150/14806 books...
#    Processed 13160/14806 books...
#    Processed 13170/14806 books...
#    Processed 13180/14806 books...
#    Processed 13190/14806 books...
#    Processed 13200/14806 books...
#    Processed 13210/14806 books...
#    Processed 13220/14806 books...
#    Processed 13230/14806 books...
#    Processed 13240/14806 books...
#    Processed 13250/14806 books...
#    Processed 13260/14806 books...
#    Processed 13270/14806 books...
#    Processed 13280/14806 books...
#    Processed 13290/14806 books...
#    Processed 13300/14806 books...
#    Processed 13310/14806 books...
#    Processed 13320/14806 books...
#    Processed 13330/14806 books...
#    Processed 13340/14806 books...
#    Processed 13350/14806 books...
#    Processed 13360/14806 books...
#    Processed 13370/14806 books...
#    Processed 13380/14806 books...
#    Processed 13390/14806 books...
#    Processed 13400/14806 books...
#    Processed 13410/14806 books...
#    Processed 13420/14806 books...
#    Processed 13430/14806 books...
#    Processed 13440/14806 books...
#    Processed 13450/14806 books...
#    Processed 13460/14806 books...
#    Processed 13470/14806 books...
#    Processed 13480/14806 books...
#    Processed 13490/14806 books...
#    Processed 13500/14806 books...
#    Processed 13510/14806 books...
#    Processed 13520/14806 books...
#    Processed 13530/14806 books...
#    Processed 13540/14806 books...
#    Processed 13550/14806 books...
#    Processed 13560/14806 books...
#    Processed 13570/14806 books...
#    Processed 13580/14806 books...
#    Processed 13590/14806 books...
#    Processed 13600/14806 books...
#    Processed 13610/14806 books...
#    Processed 13620/14806 books...
#    Processed 13630/14806 books...
#    Processed 13640/14806 books...
#    Processed 13650/14806 books...
#    Processed 13660/14806 books...
#    Processed 13670/14806 books...
#    Processed 13680/14806 books...
#    Processed 13690/14806 books...
#    Processed 13700/14806 books...
#    Processed 13710/14806 books...
#    Processed 13720/14806 books...
#    Processed 13730/14806 books...
#    Processed 13740/14806 books...
#    Processed 13750/14806 books...
#    Processed 13760/14806 books...
#    Processed 13770/14806 books...
#    Processed 13780/14806 books...
#    Processed 13790/14806 books...
#    Processed 13800/14806 books...
#    Processed 13810/14806 books...
#    Processed 13820/14806 books...
#    Processed 13830/14806 books...
#    Processed 13840/14806 books...
#    Processed 13850/14806 books...
#    Processed 13860/14806 books...
#    Processed 13870/14806 books...
#    Processed 13880/14806 books...
#    Processed 13890/14806 books...
#    Processed 13900/14806 books...
#    Processed 13910/14806 books...
#    Processed 13920/14806 books...
#    Processed 13930/14806 books...
#    Processed 13940/14806 books...
#    Processed 13950/14806 books...
#    Processed 13960/14806 books...
#    Processed 13970/14806 books...
#    Processed 13980/14806 books...
#    Processed 13990/14806 books...
#    Processed 14000/14806 books...
#    Processed 14010/14806 books...
#    Processed 14020/14806 books...
#    Processed 14030/14806 books...
#    Processed 14040/14806 books...
#    Processed 14050/14806 books...
#    Processed 14060/14806 books...
#    Processed 14070/14806 books...
#    Processed 14080/14806 books...
#    Processed 14090/14806 books...
#    Processed 14100/14806 books...
#    Processed 14110/14806 books...
#    Processed 14120/14806 books...
#    Processed 14130/14806 books...
#    Processed 14140/14806 books...
#    Processed 14150/14806 books...
#    Processed 14160/14806 books...
#    Processed 14170/14806 books...
#    Processed 14180/14806 books...
#    Processed 14190/14806 books...
#    Processed 14200/14806 books...
#    Processed 14210/14806 books...
#    Processed 14220/14806 books...
#    Processed 14230/14806 books...
#    Processed 14240/14806 books...
#    Processed 14250/14806 books...
#    Processed 14260/14806 books...
#    Processed 14270/14806 books...
#    Processed 14280/14806 books...
#    Processed 14290/14806 books...
#    Processed 14300/14806 books...
#    Processed 14310/14806 books...
#    Processed 14320/14806 books...
#    Processed 14330/14806 books...
#    Processed 14340/14806 books...
#    Processed 14350/14806 books...
#    Processed 14360/14806 books...
#    Processed 14370/14806 books...
#    Processed 14380/14806 books...
#    Processed 14390/14806 books...
#    Processed 14400/14806 books...
#    Processed 14410/14806 books...
#    Processed 14420/14806 books...
#    Processed 14430/14806 books...
#    Processed 14440/14806 books...
#    Processed 14450/14806 books...
#    Processed 14460/14806 books...
#    Processed 14470/14806 books...
#    Processed 14480/14806 books...
#    Processed 14490/14806 books...
#    Processed 14500/14806 books...
#    Processed 14510/14806 books...
#    Processed 14520/14806 books...
#    Processed 14530/14806 books...
#    Processed 14540/14806 books...
#    Processed 14550/14806 books...
#    Processed 14560/14806 books...
#    Processed 14570/14806 books...
#    Processed 14580/14806 books...
#    Processed 14590/14806 books...
#    Processed 14600/14806 books...
#    Processed 14610/14806 books...
#    Processed 14620/14806 books...
#    Processed 14630/14806 books...
#    Processed 14640/14806 books...
#    Processed 14650/14806 books...
#    Processed 14660/14806 books...
#    Processed 14670/14806 books...
#    Processed 14680/14806 books...
#    Processed 14690/14806 books...
#    Processed 14700/14806 books...
#    Processed 14710/14806 books...
#    Processed 14720/14806 books...
#    Processed 14730/14806 books...
#    Processed 14740/14806 books...
#    Processed 14750/14806 books...
#    Processed 14760/14806 books...
#    Processed 14770/14806 books...
#    Processed 14780/14806 books...
#    Processed 14790/14806 books...
#    Processed 14800/14806 books...
#    Processed 14806/14806 books...
# ✓ Processed 14806 books
#
# 🤖 Loading embedding model...
#    ✓ Loaded on CPU
#    ✓ Moved to MPS
# ✓ Model ready
#
# 🧠 Generating embeddings for book metadata...
#    Model: SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )
#    Device: mps
# Batches:   0%|          | 0/463 [00:00<?, ?it/s]
# ✓ Embeddings saved to 'calibre_book_embeddings.pkl'
#
# ================================================================================
# ✅ READY TO SEARCH!
# ================================================================================

# %%
# Cell 5: Search Function
def search(query, top_n=10, display_mode='jupyter'):
    """
    Main search function.

    Example:
        search("space opera with strong female lead")
        search("cozy mystery small town", top_n=5)
    """
    print(f"Searching for: '{query}'\n")
    results = semantic_search(query, embeddings_dict, book_metadata, model, top_n=top_n)

    if display_mode == 'jupyter':
        display_results_jupyter(results)
    else:
        display_results_text(results)

    return results

print("✓ Search function ready")
# Out:
# ✓ Search function ready

# %%
# Cell 6: Try your first search!
search("fantasy magic adventure", top_n=5)
# Out:
# Searching for: 'fantasy magic adventure'
# <h2>🔍 Search Results</h2>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 1. Untethered Magic: An Urban Fantasy Thriller
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.5715
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Steve Higgs</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 15800</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 2. On the Nature of Magic
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.5286
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Marian Womack</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 8326</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 3. Folklore, Magic, and Witchcraft: Cultural Exchanges From the Twelfth to Eighteenth Century
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.5176
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Marina Montesano</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 6362</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 4. For Love of Magic
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.4866
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Simon R. Green</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 5958</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 5. When We Were Magic
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.4786
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Sarah Gailey</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 6143</p></div>
# [{'score': np.float32(0.57145524),
#   'metadata': {'authors': 'Steve Higgs',
#    'id': 15800,
#    'title': 'Untethered Magic: An Urban Fantasy Thriller'}},
#  {'score': np.float32(0.5286398),
#   'metadata': {'authors': 'Marian Womack',
#    'id': 8326,
#    'title': 'On the Nature of Magic'}},
#  {'score': np.float32(0.5175878),
#   'metadata': {'authors': 'Marina Montesano',
#    'id': 6362,
#    'title': 'Folklore, Magic, and Witchcraft: Cultural Exchanges From the Twelfth to Eighteenth Century'}},
#  {'score': np.float32(0.4866191),
#   'metadata': {'authors': 'Simon R. Green',
#    'id': 5958,
#    'title': 'For Love of Magic'}},
#  {'score': np.float32(0.47863525),
#   'metadata': {'authors': 'Sarah Gailey',
#    'id': 6143,
#    'title': 'When We Were Magic'}}]

# %%
search("transformers nlp", top_n=5)
# Out:
# Searching for: 'transformers nlp'
# <h2>🔍 Search Results</h2>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 1. Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.7723
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Savaş Yıldırım & Meysam Asgari- Chenaghlu</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 11292</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 2. Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.7723
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Savaş Yıldırım & Meysam Asgari-Chenaghlu</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 18354</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 3. Introduction to Transformers for NLP: With the Hugging Face Library and Models to Solve Problems
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.7668
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Shashank Mohan Jain</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 10150</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 4. Introduction to Transformers for NLP: With the Hugging Face Library and Models to Solve Problems
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.7668
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Shashank Mohan Jain</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 19499</p></div>
#         <div style="border: 1px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 5px; background-color: #f9f9f9;">
#             <h3 style="margin-top: 0; color: #2c3e50;">
#                 5. Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques
#                 <span style="float: right; color: #27ae60; font-size: 0.8em;">
#                     Similarity: 0.7632
#                 </span>
#             </h3>
#         <p><strong>Authors:</strong> Savas Yildirim & Meysam Asgari-Chenaghlu</p><p style='color: #7f8c8d; font-size: 0.9em;'><strong>Calibre ID:</strong> 7784</p></div>
# [{'score': np.float32(0.77226686),
#   'metadata': {'authors': 'Savaş Yıldırım & Meysam Asgari- Chenaghlu',
#    'id': 11292,
#    'title': 'Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques'}},
#  {'score': np.float32(0.77226686),
#   'metadata': {'authors': 'Savaş Yıldırım & Meysam Asgari-Chenaghlu',
#    'id': 18354,
#    'title': 'Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques'}},
#  {'score': np.float32(0.7668112),
#   'metadata': {'authors': 'Shashank Mohan Jain',
#    'id': 10150,
#    'title': 'Introduction to Transformers for NLP: With the Hugging Face Library and Models to Solve Problems'}},
#  {'score': np.float32(0.7668112),
#   'metadata': {'authors': 'Shashank Mohan Jain',
#    'id': 19499,
#    'title': 'Introduction to Transformers for NLP: With the Hugging Face Library and Models to Solve Problems'}},
#  {'score': np.float32(0.7632168),
#   'metadata': {'authors': 'Savas Yildirim & Meysam Asgari-Chenaghlu',
#    'id': 7784,
#    'title': 'Mastering Transformers: Build State-Of-The-Art Models From Scratch With Advanced Natural Language Processing Techniques'}}]
